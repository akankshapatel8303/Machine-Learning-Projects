# %% [markdown]
# # Import matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Create a symple plot

# %%
plt.plot();

# %% [markdown]
# ## Plot a single python list

# %%
list = [3, 4, 5,7,8]
plt.plot(list)

# %% [markdown]
# ## Create two list x,y

# %%
x = [3, 6, 7, 10, 14];
y = [10, 12, 15, 12, 19];
plt.plot(x, y);

# %% [markdown]
# ## Create plot using subplot

# %%
fig, ax = plt.subplots()
ax.plot(x, y)

# Customize plot ny adding title, xLabel, ylabel
ax.set(title="Sample simple plot",
       xlabel= "x-axis",
       ylabel= "y-axis")

# Save the plot to file using savefig()
fig.savefig("../Matplotlib/simple-plot.png")

# %%
import numpy as np

# Create 100 random number btw 0 to 10 
x = np.linspace(0, 10, 100);
plt.plot(x, x**2);

# %%
#  Create a scatter plot 
fig, ax = plt.subplots(figsize=(6,3))
ax.scatter(x, np.exp(x))

# %%
fig, ax = plt.subplots(figsize=(6,3))
ax.scatter(x, np.sin(x))

# %%
# Create a python dictionary
fav_food_price = {"Butter" : 25,
                  "Eggs" : 30,
                  "Banana" : 60}
fig, ax = plt.subplots()
ax.bar(fav_food_price.keys(), fav_food_price.values())
ax.set(title="Bubbu's favourite food",
       xlabel="Food",
       ylabel="Price($)")
# Out:
# [Text(0.5, 1.0, "Bubbu's favourite food"),
#  Text(0.5, 0, 'Food'),
#  Text(0, 0.5, 'Price($)')]

# %%
fig, ax = plt.subplots()
food = list(fav_food_price.keys())
ax.barh(food, price, color='maroon');
ax.set(title="Bubbu's favourite food",
       xlabel = "Price($)",
       ylabel = "Food");
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 food = list(fav_food_price.keys())
#       3 ax.barh(food, price, color='maroon');
#       4 ax.set(title="Bubbu's favourite food",
#       5        xlabel = "Price($)",
#       6        ylabel = "Food");
#
# TypeError: 'list' object is not callable

# %%
# creating the dataset
data = {'C': 20, 'C++': 15, 'Java': 30,
        'Python': 35}
 
courses = list(data.keys())
values = list(data.values())
 
fig = plt.figure(figsize=(10, 5))
 
# creating the bar plot
plt.barh(courses, values, color='maroon')
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       1 # creating the dataset
#       2 data = {'C': 20, 'C++': 15, 'Java': 30,
#       3         'Python': 35}
# ----> 5 courses = list(data.keys())
#       6 values = list(data.values())
#       8 fig = plt.figure(figsize=(10, 5))
#
# TypeError: 'list' object is not callable

# %%
# Create a random numpy
x = np.random.randn(1000)

# Create a Histogram plot
fig, ax = plt.subplots()
ax.hist(x);

# %%
x = np.random.random(1000)

# Create a histogram plot of x
fig, ax = plt.subplots()
ax.hist(x);

# %%
# Create an empty subplot with 2 rows and 2 columns (4 subplots total)
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                             ncols=2, figsize=(10,5))
ax1.plot(x,x/4);
ax2.scatter(np.random.random(20), np.random.random(20));
ax3.bar(fav_food_price.keys(), fav_food_price.values());
ax4.hist(np.random.random(1000));

# %%
import pandas as pd
car_sales = pd.DataFrame({"Make" : ["Toyata", "Honda", "Toyata", "BMW", "Nissan", "Toyata", "Honda", "Honda", "Toyata", "Nissan"],
                         "Colour": ["White", "Red", "Blue", "Black", "White", "Green", "Blue", "Blue", "White", "White"],
                         "Odometer(KM)" : [150095, 34454, 43545, 97887, 335454, 64543, 28190, 13244, 88975, 10092],
                         "Doors" : [4, 4, 3, 5, 4, 4, 4, 4, 4, 4],
                         "Price" : ["$4,000.00", "$5,000.00", "$2,000.00", "$8,000.00", "$9,000.00", "$1,000.00", "$5,000.00", "$3,000.00", "$7,000.00", "$3,000.00"]
                         })
car_sales
# Out:
#      Make Colour  Odometer(KM)  Doors      Price
# 0  Toyata  White        150095      4  $4,000.00
# 1   Honda    Red         34454      4  $5,000.00
# 2  Toyata   Blue         43545      3  $2,000.00
# 3     BMW  Black         97887      5  $8,000.00
# 4  Nissan  White        335454      4  $9,000.00
# 5  Toyata  Green         64543      4  $1,000.00
# 6   Honda   Blue         28190      4  $5,000.00
# 7   Honda   Blue         13244      4  $3,000.00
# 8  Toyata  White         88975      4  $7,000.00
# 9  Nissan  White         10092      4  $3,000.00

# %%
car_sales["Price"].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 car_sales["Price"].plot()
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\plotting\_matplotlib\core.py:499, in MPLPlot.generate(self)
#     497 @final
# ...

# %%
car_sales["Price"] = car_sales["Price"].str.replace("$", "")
car_sales["Price"] = car_sales["Price"].str.replace(",", "")
car_sales["Price"] = car_sales["Price"].str.replace(".", "")
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer(KM)  Doors Price
# 0  Toyata  White        150095      4  4000
# 1   Honda    Red         34454      4  5000
# 2  Toyata   Blue         43545      3  2000
# 3     BMW  Black         97887      5  8000
# 4  Nissan  White        335454      4  9000
# 5  Toyata  Green         64543      4  1000
# 6   Honda   Blue         28190      4  5000
# 7   Honda   Blue         13244      4  3000
# 8  Toyata  White         88975      4  7000
# 9  Nissan  White         10092      4  3000

# %%
car_sales["Price"] = car_sales["Price"].astype (int)

# %%
car_sales["Price"].plot();

# %%
car_sales["Price"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Price"].plot(subplots=True, kind="pie");

# %%
car_sales.boxplot()
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
# Create a numpy array of random numbers of size (10,4)
x = np.random.rand(10,4)

# Turn the numpy array x into a Dataframe with columns called ['a', 'b', 'c', 'd']
df = pd.DataFrame(x, columns=["a", "b", "c", "d"])

df.plot(kind="bar")
# Out:
# <Axes: >

# %%
car_sales.plot(x="Make", y="Odometer(KM)", kind="bar");

# %%
car_sales["Odometer(KM)"].plot(kind="hist", bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
heart_disease = pd.read_csv("13.1 heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_disease["age"].hist();

# %%
heart_disease.plot.hist(figsize=(10,30), subplots=True);

# %%
# Create DataFrame with patients over 50 year old
over_50 = heart_disease[heart_disease["age"]>50]

# Create the plot
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                    c = over_50["target"])

# Customize the plot
ax.set(title="Heart Disease and Cholesterol levels",
       xlabel="Age",
       ylabel="Cholesterol");
ax.legend(*scatter.legend_elements(), title="Target")

# Add a meanline
ax.axhline(over_50["chol"].mean(),
           linestyle="--");

# %%
# Check what styles are available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use("seaborn-v0_8-whitegrid")

# %%
# Create a plot 
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"])
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

ax.legend(*scatter.legend_elements(), title="Target")

ax.axhline(over_50["chol"].mean(), 
           linestyle="--");

# %%
# Create a plot 
fig, ax = plt.subplots(figsize=(10,6))

# Plot the data
scatter = ax.scatter(over_50["age"],
                     over_50["chol"],
                     c=over_50["target"],
                    cmap="winter")
ax.set(title="Heart Disease and Cholesterol Levels",
       xlabel="Age",
       ylabel="Cholesterol")

ax.legend(*scatter.legend_elements(), title="Target")

ax.axhline(over_50["chol"].mean(), 
           linestyle="--",
          color="red");

# %%
# Save the current figure using savefig(), the file name can be anything you want 
fig.savefig("../Matplotlib/heart-disease-chol-age-plot-saved.png")
